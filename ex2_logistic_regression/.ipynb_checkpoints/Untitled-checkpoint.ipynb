# %%
import logistic_regression

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('ex2data1.txt')
print('hala')
# Out:
# hala

# %%
df
# Out:
#     exam1_score   exam2_score   y
# 0     34.623660     78.024693   0
# 1     30.286711     43.894998   0
# 2     35.847409     72.902198   0
# 3     60.182599     86.308552   1
# 4     79.032736     75.344376   1
# 5     45.083277     56.316372   0
# 6     61.106665     96.511426   1
# 7     75.024746     46.554014   1
# 8     76.098787     87.420570   1
# 9     84.432820     43.533393   1
# 10    95.861555     38.225278   0
# 11    75.013658     30.603263   0
# 12    82.307053     76.481963   1
# 13    69.364589     97.718692   1
# 14    39.538339     76.036811   0
# 15    53.971052     89.207350   1
# 16    69.070144     52.740470   1
# 17    67.946855     46.678574   0
# 18    70.661510     92.927138   1
# 19    76.978784     47.575964   1
# 20    67.372028     42.838438   0
# 21    89.676776     65.799366   1
# 22    50.534788     48.855812   0
# 23    34.212061     44.209529   0
# 24    77.924091     68.972360   1
# 25    62.271014     69.954458   1
# ...

# %%
column_names=df.columns.tolist()
plt.scatter(df[column_names[0]], df[column_names[1]], label="testing")
plt.xlabel(column_names[0])
plt.ylabel(column_names[1])

# %%
plt.title('visualization of the dataset we \n are going to use for logistic regression')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('ex2data1.txt')
column_names=df.columns.tolist()
plt.scatter(df[column_names[0]], df[column_names[1]], label="testing")
plt.xlabel(column_names[0])
plt.ylabel(column_names[1])
plt.title('visualization of the dataset we \n are going to use for logistic regression')

# %%
plt.scatter(df[column_names[1]], df[column_names[0]], label="testing")

# %%
plt.legend()

# %%
plt.show()

# %%
df
# Out:
#     exam1_score   exam2_score   y
# 0     34.623660     78.024693   0
# 1     30.286711     43.894998   0
# 2     35.847409     72.902198   0
# 3     60.182599     86.308552   1
# 4     79.032736     75.344376   1
# 5     45.083277     56.316372   0
# 6     61.106665     96.511426   1
# 7     75.024746     46.554014   1
# 8     76.098787     87.420570   1
# 9     84.432820     43.533393   1
# 10    95.861555     38.225278   0
# 11    75.013658     30.603263   0
# 12    82.307053     76.481963   1
# 13    69.364589     97.718692   1
# 14    39.538339     76.036811   0
# 15    53.971052     89.207350   1
# 16    69.070144     52.740470   1
# 17    67.946855     46.678574   0
# 18    70.661510     92.927138   1
# 19    76.978784     47.575964   1
# 20    67.372028     42.838438   0
# 21    89.676776     65.799366   1
# 22    50.534788     48.855812   0
# 23    34.212061     44.209529   0
# 24    77.924091     68.972360   1
# 25    62.271014     69.954458   1
# ...

# %%
df[df.y==1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e3e92c199b74> in <module>()
# ----> 1 df[df.y==1]
#
# /Users/gk/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'y'

# %%
df['y']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/gk/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'y'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-e3fe86cee9f2> in <module>()
# ----> 1 df['y']
#
# ...

# %%
df.columns
# Out:
# Index(['exam1_score', ' exam2_score', ' y'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('ex2data1.txt')
column_names=df.columns.tolist()
plt.scatter(df[column_names[0]], df[column_names[1]], label="testing")
plt.xlabel(column_names[0])
plt.ylabel(column_names[1])
plt.title('visualization of the dataset we \n are going to use for logistic regression')
plt.legend()

# %%
df[df.y==1]
# Out:
#     exam1_score  exam2_score  y
# 3     60.182599    86.308552  1
# 4     79.032736    75.344376  1
# 6     61.106665    96.511426  1
# 7     75.024746    46.554014  1
# 8     76.098787    87.420570  1
# 9     84.432820    43.533393  1
# 12    82.307053    76.481963  1
# 13    69.364589    97.718692  1
# 15    53.971052    89.207350  1
# 16    69.070144    52.740470  1
# 18    70.661510    92.927138  1
# 19    76.978784    47.575964  1
# 21    89.676776    65.799366  1
# 24    77.924091    68.972360  1
# 25    62.271014    69.954458  1
# 26    80.190181    44.821629  1
# 30    61.379289    72.807887  1
# 31    85.404519    57.051984  1
# 33    52.045405    69.432860  1
# 37    64.176989    80.908061  1
# 40    83.902394    56.308046  1
# 42    94.443368    65.568922  1
# 46    77.193035    70.458200  1
# 47    97.771599    86.727822  1
# 48    62.073064    96.768824  1
# 49    91.564974    88.696293  1
# 50    79.944818    74.163119  1
# 51    99.272527    60.999031  1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('ex2data1.txt')
column_names=df.columns.tolist()
not_admitted_df=df[df.y==0]
admitted_df=df[df.y==1]

plt.scatter(admitted_df[column_names[0]], admitted_df[column_names[1]], label="admitted", color="blue")
plt.scatter(not_admitted_df[column_names[0]], not_admitted_df[column_names[1]], label="not admitted", color="red")
plt.xlabel(column_names[0])
plt.ylabel(column_names[1])
plt.title('visualization of the dataset we \n are going to use for logistic regression')
plt.legend()
plt.show()

# %%
Math.exp(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a1cc8cde6c7a> in <module>()
# ----> 1 Math.exp(2)
#
# NameError: name 'Math' is not defined

# %%
math.exp(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6318d0f102f3> in <module>()
# ----> 1 math.exp(2)
#
# NameError: name 'math' is not defined

# %%
import math as math

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %%
e**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2543f9cf1d02> in <module>()
# ----> 1 e**2
#
# NameError: name 'e' is not defined

# %%
def sigmoid(x):
    return 1/(1+math.exp(-x))

# %%
sigmoid(0)
# Out:
# 0.5

# %%
sigmoid(1/2)
# Out:
# 0.6224593312018546
